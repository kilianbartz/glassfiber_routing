# %%
import polars as pl
ilp = pl.read_ndjson("results_uv run ipy.py_625.jsonl")
astar = pl.read_ndjson("results_.._astar-current -s static -i 10_6-2-5.jsonl")
astar.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────────┬─────────┬────────────┬─────────┬─────────────────────────────────┐
# │ instance                ┆ success ┆ total_time ┆ missing ┆ output                          │
# │ ---                     ┆ ---     ┆ ---        ┆ ---     ┆ ---                             │
# │ struct[3]               ┆ bool    ┆ f64        ┆ i64     ┆ struct[4]                       │
# ╞═════════════════════════╪═════════╪════════════╪═════════╪═════════════════════════════════╡
# │ {6,[[2, 7], [3, 12]],0} ┆ true    ┆ 0.000032   ┆ 0       ┆ {"astar",true,{[[[4, 1], [5, 1… │
# │ {6,[[2, 7], [3, 13]],1} ┆ true    ┆ 0.000022   ┆ 0       ┆ {"astar",true,{null,[[[1, 1], … │
# │ {6,[[2, 7], [3, 18]],2} ┆ true    ┆ 0.000026   ┆ 0       ┆ {"astar",true,{null,[[[1, 1], … │
# │ {6,[[2, 7], [3, 19]],3} ┆ true    ┆ 0.000019   ┆ 0       ┆ {"astar",true,{null,[[[1, 1], … │
# │ {6,[[2, 7], [3, 24]],4} ┆ true    ┆ 0.000026   ┆ 0       ┆ {"astar",true,{null,[[[1, 1], … │
# └─────────────────────────┴─────────┴────────────┴─────────┴─────────────────────────────────┘

# %%
ilp.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────────┬─────────┬────────────┬─────────┬─────────────────────────────────┐
# │ instance                ┆ success ┆ total_time ┆ missing ┆ output                          │
# │ ---                     ┆ ---     ┆ ---        ┆ ---     ┆ ---                             │
# │ struct[3]               ┆ bool    ┆ f64        ┆ i64     ┆ struct[4]                       │
# ╞═════════════════════════╪═════════╪════════════╪═════════╪═════════════════════════════════╡
# │ {6,[[2, 7], [3, 12]],0} ┆ true    ┆ 0.022908   ┆ 0       ┆ {"ilp",true,{[[[1, 0], [1, 1]]… │
# │ {6,[[2, 7], [3, 13]],1} ┆ true    ┆ 0.023477   ┆ 0       ┆ {"ilp",true,{[[[1, 0], [1, 1]]… │
# │ {6,[[2, 7], [3, 18]],2} ┆ true    ┆ 0.020834   ┆ 0       ┆ {"ilp",true,{[[[1, 0], [1, 1]]… │
# │ {6,[[2, 7], [3, 19]],3} ┆ true    ┆ 0.015795   ┆ 0       ┆ {"ilp",true,{[[[1, 0], [1, 1]]… │
# │ {6,[[2, 7], [3, 24]],4} ┆ true    ┆ 0.024732   ┆ 0       ┆ {"ilp",true,{[[[1, 0], [1, 1]]… │
# └─────────────────────────┴─────────┴────────────┴─────────┴─────────────────────────────────┘

# %%
joined = ilp.join(
    astar,
    on="instance",  # The common column to match on
    how="inner",      # The type of join (can be "left", "outer", etc.)
    suffix="_astar"
)
joined.head()
# Out:
# shape: (5, 9)
# ┌────────────┬─────────┬────────────┬─────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ instance   ┆ success ┆ total_time ┆ missing ┆ … ┆ success_as ┆ total_tim ┆ missing_a ┆ output_as │
# │ ---        ┆ ---     ┆ ---        ┆ ---     ┆   ┆ tar        ┆ e_astar   ┆ star      ┆ tar       │
# │ struct[3]  ┆ bool    ┆ f64        ┆ i64     ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆         ┆            ┆         ┆   ┆ bool       ┆ f64       ┆ i64       ┆ struct[4] │
# ╞════════════╪═════════╪════════════╪═════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ {6,[[2,    ┆ true    ┆ 0.022908   ┆ 0       ┆ … ┆ true       ┆ 0.000032  ┆ 0         ┆ {"astar", │
# │ 7], [3,    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ true,{[[[ │
# │ 12]],0}    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ 4, 1],    │
# │            ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ [5, 1…    │
# │ {6,[[2,    ┆ true    ┆ 0.023477   ┆ 0       ┆ … ┆ true       ┆ 0.000022  ┆ 0         ┆ {"astar", │
# │ 7], [3,    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ true,{nul │
# │ 13]],1}    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ l,[[[1,   │
# │            ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ 1], …     │
# │ {6,[[2,    ┆ true    ┆ 0.020834   ┆ 0       ┆ … ┆ true       ┆ 0.000026  ┆ 0         ┆ {"astar", │
# │ 7], [3,    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ true,{nul │
# │ 18]],2}    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ l,[[[1,   │
# │            ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ 1], …     │
# │ {6,[[2,    ┆ true    ┆ 0.015795   ┆ 0       ┆ … ┆ true       ┆ 0.000019  ┆ 0         ┆ {"astar", │
# │ 7], [3,    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ true,{nul │
# │ 19]],3}    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ l,[[[1,   │
# │            ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ 1], …     │
# │ {6,[[2,    ┆ true    ┆ 0.024732   ┆ 0       ┆ … ┆ true       ┆ 0.000026  ┆ 0         ┆ {"astar", │
# │ 7], [3,    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ true,{nul │
# │ 24]],4}    ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ l,[[[1,   │
# │            ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ 1], …     │
# └────────────┴─────────┴────────────┴─────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
len(joined)
# Out:
# 628416

# %%
reverse_problemcases = joined.filter(
    (pl.col("success") == False) & (pl.col("success_astar") == True)
)

print(reverse_problemcases)
# Out:
# shape: (0, 9)
# ┌───────────┬─────────┬────────────┬─────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ instance  ┆ success ┆ total_time ┆ missing ┆ … ┆ success_as ┆ total_time ┆ missing_a ┆ output_as │
# │ ---       ┆ ---     ┆ ---        ┆ ---     ┆   ┆ tar        ┆ _astar     ┆ star      ┆ tar       │
# │ struct[3] ┆ bool    ┆ f64        ┆ i64     ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆         ┆            ┆         ┆   ┆ bool       ┆ f64        ┆ i64       ┆ struct[4] │
# ╞═══════════╪═════════╪════════════╪═════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# └───────────┴─────────┴────────────┴─────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
problemcases = joined.filter(
    (pl.col("success") == True) & (pl.col("success_astar") == False)
)

problemcases
# Out:
# shape: (61_195, 9)
# ┌────────────┬─────────┬────────────┬─────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ instance   ┆ success ┆ total_time ┆ missing ┆ … ┆ success_as ┆ total_tim ┆ missing_a ┆ output_as │
# │ ---        ┆ ---     ┆ ---        ┆ ---     ┆   ┆ tar        ┆ e_astar   ┆ star      ┆ tar       │
# │ struct[3]  ┆ bool    ┆ f64        ┆ i64     ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │            ┆         ┆            ┆         ┆   ┆ bool       ┆ f64       ┆ i64       ┆ struct[4] │
# ╞════════════╪═════════╪════════════╪═════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ {6,[[2,    ┆ true    ┆ 0.027224   ┆ 0       ┆ … ┆ false      ┆ 0.000043  ┆ 1         ┆ {"astar", │
# │ 18], [3,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 19], [13,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ 33]…       ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[2,    ┆ true    ┆ 0.031772   ┆ 0       ┆ … ┆ false      ┆ 0.000047  ┆ 1         ┆ {"astar", │
# │ 18], [4,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 13], [5,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ 19]]…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[2,    ┆ true    ┆ 0.046752   ┆ 0       ┆ … ┆ false      ┆ 0.000047  ┆ 1         ┆ {"astar", │
# │ 18], [4,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 13], [5,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ 25]]…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[2,    ┆ true    ┆ 0.076385   ┆ 0       ┆ … ┆ false      ┆ 0.000047  ┆ 1         ┆ {"astar", │
# │ 18], [4,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 13], [5,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ 32]]…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[2,    ┆ true    ┆ 0.030217   ┆ 0       ┆ … ┆ false      ┆ 0.000046  ┆ 1         ┆ {"astar", │
# │ 18], [4,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 13], [5,   ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ 33]]…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ …          ┆ …       ┆ …          ┆ …       ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ {6,[[13,   ┆ true    ┆ 0.059219   ┆ 0       ┆ … ┆ false      ┆ 0.000127  ┆ 1         ┆ {"astar", │
# │ 35], [18,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 34], …     ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ [24,…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[13,   ┆ true    ┆ 0.052063   ┆ 0       ┆ … ┆ false      ┆ 0.000124  ┆ 1         ┆ {"astar", │
# │ 35], [18,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 34], …     ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ [24,…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[13,   ┆ true    ┆ 0.052463   ┆ 0       ┆ … ┆ false      ┆ 0.000105  ┆ 1         ┆ {"astar", │
# │ 35], [19,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 34], …     ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ [25,…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[13,   ┆ true    ┆ 0.067773   ┆ 0       ┆ … ┆ false      ┆ 0.000113  ┆ 2         ┆ {"astar", │
# │ 35], [19,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 34], …     ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ [30,…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# │ {6,[[18,   ┆ true    ┆ 0.065221   ┆ 0       ┆ … ┆ false      ┆ 0.000057  ┆ 1         ┆ {"astar", │
# │ 25], [19,  ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ false,{nu │
# │ 34], …     ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ll,null,n │
# │ [30,…      ┆         ┆            ┆         ┆   ┆            ┆           ┆           ┆ ull…      │
# └────────────┴─────────┴────────────┴─────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
joined.select(pl.sum("total_time"))
# Out:
# shape: (1, 1)
# ┌──────────────┐
# │ total_time   │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 31498.339895 │
# └──────────────┘

# %%
joined.select(pl.sum("total_time_astar"))
# Out:
# shape: (1, 1)
# ┌──────────────────┐
# │ total_time_astar │
# │ ---              │
# │ f64              │
# ╞══════════════════╡
# │ 43.689365        │
# └──────────────────┘

# %%
not_solved_astar = joined.filter(
    pl.col("success_astar") == False
)
unsolvable = joined.filter(
    pl.col("success") == False
)
import matplotlib.pyplot as plt
import polars as pl

def plot_performance_comparison(joined, problemcases, not_solved):
    """
    Displays two side-by-side bar plots:
    1. Comparison of dataset lengths (joined, problemcases, not_solved).
    2. Comparison of total time sums (total_time vs total_time_astar).
    
    Parameters:
    - joined: Polars DataFrame containing 'total_time' and 'total_time_astar' columns.
    - problemcases: Polars DataFrame (used for length count).
    - not_solved: Polars DataFrame (used for length count).
    """
    
    # --- Prepare Data for Plot 1 (Counts) ---
    count_labels = ['Total Instances', 'Unsolved Instances (A*)', 'Unsolvable Instances']
    count_values = [len(joined), len(problemcases), len(not_solved)]
    count_colors = ['#1f77b4', '#ff7f0e', '#d62728'] # Blue, Orange, Red

    # --- Prepare Data for Plot 2 (Time Sums) ---
    # We use .item() to extract the scalar value from the resulting 1x1 DataFrame
    total_time_sum = joined.select(pl.sum("total_time")).item()
    astar_time_sum = joined.select(pl.sum("total_time_astar")).item()
    
    time_labels = ['Total Time ILP', 'Total Time A*']
    time_values = [total_time_sum, astar_time_sum]
    time_colors = ['#2ca02c', '#9467bd'] # Green, Purple

    # --- Create Plots ---
    fig, axes = plt.subplots(1, 2, figsize=(12, 6), dpi=300)

    # Plot 1: Dataset Counts
    axes[0].bar(count_labels, count_values, color=count_colors)
    axes[0].set_title('Effectiveness of the A* Algorithm')
    axes[0].set_ylabel('Count')
    
    # Add value labels on top of bars
    for i, v in enumerate(count_values):
        axes[0].text(i, v, str(v), ha='center', va='bottom', fontweight='bold')

    # Plot 2: Time Comparison
    axes[1].bar(time_labels, time_values, color=time_colors)
    axes[1].set_title('Efficiency Comparison')
    axes[1].set_ylabel('Seconds')

    
    # Add value labels on top of bars
    for i, v in enumerate(time_values):
        axes[1].text(i, v, f"{v:.2f}", ha='center', va='bottom', fontweight='bold')

    plt.tight_layout()
    plt.show()

plot_performance_comparison(joined, not_solved_astar, unsolvable)
